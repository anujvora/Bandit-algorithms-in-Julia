# %%
func_str = "cos"

# Convert the string to a Symbol
func_sym = Symbol(func_str)

# Get the function object from the Main module (or another module if needed)
callable_func = getfield(Main, func_sym)

# Call the function
value = callable_func(pi)
println(value) # Output: -1.0
# Out:
# -1.0

# %%
# Out:
# 0
